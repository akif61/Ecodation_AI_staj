# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('data/cc_general.csv')

# %%
dataset.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %%
print(dataset.columns)
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
# nümerik değerler üzerinde NaN değerlerin miktarı gösterildi
categorical = [var for var in dataset.columns if dataset[var].dtype != 'O']

cat1 = [var for var in categorical if dataset[var].isnull().sum()!=0]

print(dataset[categorical].isnull().sum())
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Tüm NaN değerlerin mevcut kolondaki medyana eşitlenerek kolondaki sayısal dengeyi değiştirmemek, aynı zamanda da NaN değerlerin hata çıkarmasını engelledik.
numerical = [col for col in dataset.columns if dataset[col].dtypes != 'O']

for df1 in [dataset]:
    for col in numerical:
        col_median = dataset[col].median()
        df1[col].fillna(col_median, inplace=True)

# %%
categorical = [var for var in dataset.columns if dataset[var].dtype != 'O']

cat1 = [var for var in categorical if dataset[var].isnull().sum()!=0]

print(dataset[categorical].isnull().sum())
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
dataset = dataset.drop(['CUST_ID'], axis = 1)

# %%
dataset.head(25)
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     40.900749           0.818182      95.40              0.00
# 1   3202.467416           0.909091       0.00              0.00
# 2   2495.148862           1.000000     773.17            773.17
# 3   1666.670542           0.636364    1499.00           1499.00
# 4    817.714335           1.000000      16.00             16.00
# 5   1809.828751           1.000000    1333.28              0.00
# 6    627.260806           1.000000    7091.01           6402.63
# 7   1823.652743           1.000000     436.20              0.00
# 8   1014.926473           1.000000     861.49            661.49
# 9    152.225975           0.545455    1281.60           1281.60
# 10  1293.124939           1.000000     920.12              0.00
# 11   630.794744           0.818182    1492.18           1492.18
# 12  1516.928620           1.000000    3217.99           2500.23
# 13   921.693369           1.000000    2137.93            419.96
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
sns.pairplot(dataset)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dataset_scaled = scaler.fit_transform(dataset)

# %%
from sklearn.cluster import KMeans

#elbow
distance = []

for i in range(1,20):
    kmeans = KMeans(n_clusters = int(i), init = 'k-means++', random_state = 42)
    kmeans.fit(dataset_scaled)
    distance.append(kmeans.inertia_)
    
plt.figure()
plt.plot(range(1,20), distance)
plt.title('dirsek')
plt.xlabel('küme sayısı')
plt.ylabel('inetria')
plt.show()

# %%
kmeans_real = KMeans(n_clusters = 8 , init= 'k-means++', random_state = 42)
y_cluster = kmeans_real.fit_predict(dataset_scaled)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
principal_comp = pca.fit_transform(dataset_scaled)
pca_df = pd.DataFrame(data = principal_comp, columns = ['pca1', 'pca2'])
pca_df = pd.concat([pca_df, pd.DataFrame({'cluster': y_cluster})], axis = 1)

# %%
pca_df.head(10)
# Out:
#        pca1      pca2  cluster
# 0 -1.683650 -1.072236        0
# 1 -1.134089  2.509162        4
# 2  0.969403 -0.383594        3
# 3 -0.888222  0.004655        0
# 4 -1.600022 -0.683791        0
# 5  0.252966 -0.776386        2
# 6  6.350162 -0.704545        1
# 7  0.276081 -1.288145        2
# 8 -0.442173 -0.459488        0
# 9 -0.563832 -0.366713        5

# %%
plt.figure(figsize = (10,10))
plt.scatter(pca_df['pca1'],pca_df['pca2'], c = pca_df['cluster'], s = 15)
plt.xlabel('pca1')
plt.ylabel('pca2')
plt.title('clustering')
plt.show()

# %%
plt.figure()
plt.title('heatmap')
sns.heatmap(pca_df)
# Out:
# <AxesSubplot:title={'center':'heatmap'}>

# %%
 #end of code
